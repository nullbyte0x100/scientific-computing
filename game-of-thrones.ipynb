# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
#read the data
data=pd.read_csv('character-deaths.csv')
data.head

# %%
#clear the blanks
data=data.dropna()
data.head
